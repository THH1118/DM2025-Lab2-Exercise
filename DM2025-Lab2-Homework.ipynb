# %% [markdown]
# ### **Student Information**
# Name:洪梓勛
#
# Student ID:113061541
#
# GitHub ID:THH1118
#
# Kaggle name:NTHU_113061541
#
# Kaggle private scoreboard snapshot:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](https://github.com/THH1118/DM2025-Lab2-Exercise/blob/main/pics/lab2_deadlines.png?raw=1)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
#
# ## 1. Model Development (10 pts Required)
#
#
# ### 1.1 Preprocessing Steps
#
# Data Sources and Merging
#
# *  First, merge split_df and emotion_df on id to obtain the labels.
#
# *  Then flatten posts_raw with json_normalize to create posts, and merge by id with both the train and test dataframes.
#
# *  Use split == "train" with dropna(emotion) to obtain the training set; use split == "test" to obtain the test set.
#
# Text Cleaning
#
# *  Soft version: retain emotion-related punctuation (e.g., ! ? . , ; : ( ) ' " - _ /), remove URLs, @mentions, and #, and collapse extra whitespace — preserving more tone cues.
#
# *  Hard version: remove non-alphanumeric characters and all punctuation (keep spaces); cleaner and more semantics-oriented, reducing noise and facilitating semantic embeddings.
#
# *  Both versions produce clean_soft and clean_hard for the train/test sets to support subsequent TF-IDF and Count pipelines as well as SBERT TTA.
#
#
# ### 1.2 Feature Engineering Steps
#
# A. TF-IDF (Word + Char)
#
# *  Word n-grams: (1,2); Char n-grams: (2,6); combined via FeatureUnion.
#
# *  Fit/transform on Soft text: X_all_tfidf (train), X_test_tfidf (test).
#
# *  Settings: max_features=22000, min_df=2, max_df=0.995, sublinear_tf=True.
#
# B. Count Features (for NB-SVM)
#
# *  Use CountVectorizer separately for word/char, then hstack the matrices.
#
# *  Core step: compute the per-class log-count ratio rc and multiply features by
#
# rc , forming an NB-SVM style input to enhance class separability.
#
# C. SBERT Sentence Embeddings
#
# *  Encoders: all-mpnet-base-v2, paraphrase-mpnet-base-v2.
#
# *  TTA strategy: encode both Soft and Hard text versions and average predictions at inference.
#
# *  Batching: batch_size=64; automatically selects cuda/cpu.
#
# D. Class Imbalance Handling (for the XGBoost route)
#
# *  BorderlineSMOTE: oversample within each training fold (with sampling_strategy lower-bounded at 0.55× the majority class) to strengthen minority decision boundaries.
#
# *  Effective Number Weights: compute class weights with β=0.999 and pass them as sample_weight to XGBoost.
#
# ###In short: this combines surface form features (TF-IDF/Count) with semantic embeddings (SBERT) for complementarity, and leverages TTA plus imbalance handling to improve generalization.
#
# ### 1.3 Explanation of Your Model
#
# ###Overall Architecture: 6 Base Models + Two-Stage Stacking + Three Post-Processing Steps
#
# (I) Base Models (Routes A–F)
#
# A: TF-IDF + LinearSVC (Calibrated)
#
# *  Apply isotonic calibration to the SVC decision function to obtain probabilities.
#
# *  Produce OOF probabilities and test probabilities, which are concatenated later as stacking features.
#
# B: TF-IDF + Logistic Regression (Calibrated)
#
# *  Multinomial LR with saga, class_weight="balanced", and isotonic probability calibration.
#
# C: NB-SVM (log-count ratio + LinearSVC with class weights)
#
# *  For each class, compute the log-count ratio and train a linear classifier.
#
# *  Convert margins to probabilities via sigmoid, then row-wise normalize.
#
# D: SBERT (all-mpnet) + XGBoost (TTA)
#
# *  Train on Soft embeddings; at inference, average Soft/Hard predictions.
#
# *  Combine BorderlineSMOTE + Effective-number weighting for class balance.
#
# *  XGBClassifier with max_depth=6, n_estimators=420, subsample=0.9, colsample_bytree=0.95.
#
# E: SBERT (all-mpnet) + Calibrated LinearSVC (TTA)
#
# *  Train on Soft embeddings; average Soft/Hard at inference; apply probability calibration.
#
# F: SBERT (paraphrase-mpnet) + XGBoost (TTA)
#
# *  Same as D, but using paraphrase-mpnet-base-v2 embeddings.
#
# ##Each route uses 5-fold Stratified CV to generate OOF probabilities and test probabilities. The code prints the OOF macro-F1 at the end of every route.
#
# (II) Two-Stage Stacking (Blending)
#
# *  Stacker: LogisticRegression(multi_class="multinomial", class_weight="balanced").
#
# *  Input features: concatenate the six routes’ OOF probabilities to shape [N, 6*L].
#
# *  Outputs:
#
#    *  OOF: proba_oof_bl (initial blended probabilities) and [STACK(raw)] OOF macro-F1.
#
# (III) Post-Processing (Three Steps)
#
# 1. Per-Class Temperature Scaling (coordinate search)
#
# *  For each class j, find the best temperature, adjust, then renormalize.
#
# *  Goal: maximize OOF macro-F1.
#
# 2. Per-Class Logit Bias
#
# *  Convert blended probabilities to logits learn a bias  for each class, and compute softmax(logits + b).
#
# *  Use grid search + two rounds of coordinate descent to keep improving OOF macro-F1.
#
# 3. Pairwise Margin Flip
#
# *  From the OOF confusion matrix, pick the top-K most confused class pairs (the code uses top 4).
#
# *  At prediction time, if a sample is predicted as A but P(B)/P(A) exceeds a threshold τ, flip to B.
#
# *  Each pair’s threshold τ is found on OOF via coordinate search.
#
# ###Applying to the Test Set
#
# *  Sequentially apply (1) temperature scaling, (2) class-wise logit bias, and (3) pairwise flip to obtain pred_tst, then output submission_final_v3.csv.
#
# ---
#
# ## 2. Bonus Section (5 pts Optional)
#
#
# ### 2.1 Mention Different Things You Tried
#
# (1) Dual-channel cleaning
#
# *  soft: Keep emotion-related punctuation (! ? , . etc.) and common symbols; remove links and mentions (http/@/#).
#
# *  hard: Stronger denoising; keep only alphanumerics and spaces for cleaner semantics.
#
# *  Many routes train mainly on soft, while hard is used for TTA averaging, which slightly improves stability.
#
# ###Why I do this: Emotion tasks are sensitive to punctuation, so the soft channel is more stable for TF-IDF/traditional models. For sentence embeddings (SBERT), the hard channel sometimes acts as complementary noise suppression; using it for TTA improves generalization.
#
# (2) Encoders & classifiers
#
# *  Encoders: all-mpnet-base-v2, paraphrase-mpnet-base-v2.
# Encode both soft/hard texts and do TTA: proba = (soft + hard) / 2.
#
# *  Classifiers
#     *  XGBoost (multi:softprob):
# Standard setup: learning_rate ≈ 0.10, max_depth = 6, n_estimators ≈ 420, subsample ≈ 0.9, colsample_bytree ≈ 0.95.
#
#     *  Calibrated SVC.
#
# *  Imbalance handling
#
#     *  BorderlineSMOTE (k=3): per-fold class counts; upsample minority classes to ~55% of the majority.
#
#     *  Effective-Number class weighting: beta = 0.999 → converted to sample_weight.
#
# *  What I tried / observations
#
#     *  TTA (soft/hard): provides small but consistent gains on SBERT+XGB routes.
#
#     *  SMOTE ratio: ~0.55 is the most stable; higher ratios over-smooth the decision boundary.
#
#     *  Two encoders are complementary: mixing all-mpnet and para-mpnet is more stable on OOF than a single path.
#
# ###Why I do this: Sentence embeddings + tree models suit nonlinear decision boundaries; pairing with TTA adds noise robustness.
#
# (3) Second-stage stacking
#
# *  Inputs: Class probabilities from six routes (A/B/C and SBERT+XGB and/or SVC) concatenated horizontally.
#
# *  Meta model: LogisticRegression (multinomial, class_weight='balanced').
#
# *  Label alignment: All routes map to the global labels index to avoid class-order mismatches from folds/encoders.
#
# *  Comparison:
# Trained the meta learner directly on OOF vs. introducing an external holdout set.
# Result: Training the meta only on OOF, then applying conservative post-processing, achieved the best Kaggle performance. Although the holdout (OOF-hold) reported a higher macro-F1, its Kaggle score was lower. Likely reasons:
#
#     *  The distribution of holdout still differs from the Kaggle test set, so choices of α, temperatures, and biases may have overfit the holdout.
#
#     *  Convex averaging weights derived from OOF macro-F1 inherently carry data-leakage risk; combining them with holdout did not yield as stable gains as expected.
#
#     *  BBSE helps mainly under strong prior-shift; domain shift may be modest, so enabling BBSE introduced extra noise instead.
#
# ### 2.2 Mention Insights You Gained
#
# Here are my takeaways from this assignment:
#
# (1) I originally thought semantic embeddings (SBERT) would always outperform surface-level features (TF-IDF/character n-grams), but in practice I found that “prosodic” signals—emotion punctuation, emphasis symbols, elongated words, emojis—are highly sensitive to emotion classes.
#
# (2) Dual cleaning + TTA truly reduces variance. Averaging predictions from the Soft pipeline (keeps tone cues) and the Hard pipeline (pure semantics) makes boundary cases less likely to fail due to either representation being overly extreme. This text-level TTA is especially beneficial for emotion tasks.
#
# (3) Emotion labels are often imbalanced—data imbalance is a near-universal issue. Using BorderlineSMOTE plus Effective-number class weighting makes the minority classes better represented at the decision boundary—it’s not just “adding more,” but adding where it matters.
#
# (4) Concatenating OOF probabilities from six models allows the stacker to learn “who is reliable when.” For example, TF-IDF + SVC tends to be more stable on strongly tonal sentences, while SBERT + XGB is more reliable when semantics are ambiguous but the context is complete.
#
# ---

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# ##get data

# %%
# !pip install -q kaggle
import json, os
KAGGLE_USERNAME = "nthu113061541"
KAGGLE_KEY = "9f7dc47fdde8936c731b7c129b5fa4ca"
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
with open(os.path.expanduser("~/.kaggle/kaggle.json"), "w") as f:
    json.dump({"username": KAGGLE_USERNAME, "key": KAGGLE_KEY}, f)
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dm-lab-2-private-competition
# !unzip -o dm-lab-2-private-competition.zip -d data/
# !ls -lh data/
# Out:
# ...
#   0% 0.00/3.61M [00:00<?, ?B/s]
# 100% 3.61M/3.61M [00:00<00:00, 1.02GB/s]
# Archive:  dm-lab-2-private-competition.zip
#   inflating: data/data_identification.csv
#   inflating: data/emotion.csv
#   inflating: data/final_posts.json
#   inflating: data/samplesubmission.csv
# total 19M
# -rw-r--r-- 1 root root 925K Oct  8 06:55 data_identification.csv
# -rw-r--r-- 1 root root 682K Oct  8 06:55 emotion.csv
# -rw-r--r-- 1 root root  17M Oct  8 06:55 final_posts.json
# -rw-r--r-- 1 root root 287K Oct  8 06:55 samplesubmission.csv

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
### Add the code related to the preprocessing steps in cells inside this section
# !pip install -q sentence-transformers xgboost scikit-learn imbalanced-learn

import re, warnings, math
import numpy as np
import pandas as pd
from collections import Counter

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.calibration import CalibratedClassifierCV
from scipy import sparse

from sentence_transformers import SentenceTransformer
import xgboost as xgb
import torch
from imblearn.over_sampling import BorderlineSMOTE

warnings.filterwarnings("ignore")
SEED = 42
np.random.seed(SEED)
print("Using device:", "GPU" if torch.cuda.is_available() else "CPU")

# load data & JSON
emotion_df = pd.read_csv("/content/data/emotion.csv")
split_df   = pd.read_csv("/content/data/data_identification.csv")
df = pd.merge(split_df, emotion_df, on="id", how="left")
train_df = df[df["split"]=="train"].dropna(subset=["emotion"]).copy()
test_df  = df[df["split"]=="test"].copy()

posts_raw = pd.read_json("/content/data/final_posts.json")
posts = pd.json_normalize(posts_raw["root"])
posts = posts[['_source.post.post_id', '_source.post.text']].rename(
    columns={'_source.post.post_id':'id','_source.post.text':'text'}
)
train_df = pd.merge(train_df, posts, on="id", how="left")
test_df  = pd.merge(test_df,  posts, on="id", how="left")

print(f"training data: {len(train_df)} | testing data: {len(test_df)}")

# text cleaning
def clean_text_soft(tx):
    tx = str(tx)
    tx = re.sub(r"http\S+|www\S+"," ", tx)
    tx = re.sub(r"@\w+"," ", tx)
    tx = tx.replace("#", "")
    tx = re.sub(r"[^A-Za-z0-9\s\!\?\.\,;\:\(\)\'\"\-_/]|(?<=\s)[_](?=\s)"," ", tx)  # keep emotional
    tx = re.sub(r"\s+"," ", tx).strip()
    return tx.lower()

def clean_text_hard(tx):
    tx = str(tx)
    tx = re.sub(r"http\S+|www\S+|@\w+|#"," ", tx)
    tx = re.sub(r"[^A-Za-z0-9\s]"," ", tx)
    tx = re.sub(r"\s+"," ", tx).strip()
    return tx.lower()

train_df["clean_soft"] = train_df["text"].apply(clean_text_soft)
train_df["clean_hard"] = train_df["text"].apply(clean_text_hard)
test_df["clean_soft"]  = test_df["text"].apply(clean_text_soft)
test_df["clean_hard"]  = test_df["text"].apply(clean_text_hard)

X_soft_train = train_df["clean_soft"].values
X_hard_train = train_df["clean_hard"].values
y_train      = train_df["emotion"].values
X_soft_test  = test_df["clean_soft"].values
X_hard_test  = test_df["clean_hard"].values

labels       = np.unique(y_train)
L            = len(labels)
label2idx    = {c:i for i,c in enumerate(labels)}
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
# Out:
# Using device: GPU
# training data: 47890 | testing data: 16281

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
### Add the code related to the feature engineering steps in cells inside this section
# TF-IDF feature
tfidf_word = TfidfVectorizer(
    analyzer="word", ngram_range=(1,2),
    max_features=22000, min_df=2, max_df=0.995, sublinear_tf=True
)
tfidf_char = TfidfVectorizer(
    analyzer="char", ngram_range=(2,6),
    min_df=2, sublinear_tf=True
)
tfidf_union = FeatureUnion([("word", tfidf_word), ("char", tfidf_char)])
X_all_tfidf  = tfidf_union.fit_transform(X_soft_train)
X_test_tfidf = tfidf_union.transform(X_soft_test)

# Count feature
cv_word = CountVectorizer(analyzer="word", ngram_range=(1,2), min_df=2, max_df=0.995)
cv_char = CountVectorizer(analyzer="char", ngram_range=(2,6), min_df=2)
X_cnt_word = cv_word.fit_transform(X_soft_train)
X_cnt_char = cv_char.fit_transform(X_soft_train)
X_cnt      = sparse.hstack([X_cnt_word, X_cnt_char]).tocsr()
X_cnt_test = sparse.hstack([cv_word.transform(X_soft_test), cv_char.transform(X_soft_test)]).tocsr()

le_full    = LabelEncoder().fit(y_train)
y_enc_full = le_full.transform(y_train)
C = len(le_full.classes_)

def log_count_ratio(X, y_enc, c):
    p = 1 + X[y_enc==c].sum(0)
    q = 1 + X[y_enc!=c].sum(0)
    r = np.log(p / q)
    return np.asarray(r).ravel()

# SBERT
def encode_sbert(encoder_name, texts):
    model = SentenceTransformer(encoder_name, device='cuda' if torch.cuda.is_available() else 'cpu')
    emb = model.encode(list(texts), show_progress_bar=True, batch_size=64)
    return emb

# two encoder
encoders = [
    'all-mpnet-base-v2',
    'paraphrase-mpnet-base-v2',
]

# build SBERT vector（soft / hard ）
sbert_soft = {}
sbert_hard = {}
for name in encoders:
    print(f"\n Encoding ({name}) on SOFT text ...")
    sbert_soft[name] = encode_sbert(name, X_soft_train), encode_sbert(name, X_soft_test)
    print(f" Encoding ({name}) on HARD text ...")
    sbert_hard[name] = encode_sbert(name, X_hard_train), encode_sbert(name, X_hard_test)

# XGBoost
le_xgb = LabelEncoder().fit(y_train)
y_train_enc = le_xgb.transform(y_train)

def effective_num_weights(y, num_classes, beta=0.999):
    binc = np.bincount(y, minlength=num_classes).astype(float)
    eff_num = 1.0 - np.power(beta, binc)
    cls_w = (1.0 - beta) / np.clip(eff_num, 1e-8, None)
    cls_w = cls_w / cls_w.mean()
    return cls_w
# Out:
#  Encoding (all-mpnet-base-v2) on SOFT text ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...
# Batches:   0%|          | 0/255 [00:00<?, ?it/s]
#  Encoding (all-mpnet-base-v2) on HARD text ...
# ...
# Batches:   0%|          | 0/255 [00:00<?, ?it/s]
#  Encoding (paraphrase-mpnet-base-v2) on SOFT text ...
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
### Add the code related to the model implementation steps in cells inside this section
# A：TF-IDF + LinearSVC
oof_A = np.zeros((len(X_soft_train), L))
test_A_folds = []
for tr_idx, va_idx in skf.split(X_all_tfidf, y_train):
    X_tr, X_va = X_all_tfidf[tr_idx], X_all_tfidf[va_idx]
    y_tr, y_va = y_train[tr_idx], y_train[va_idx]
    base = LinearSVC(C=1.0, class_weight="balanced", random_state=SEED)
    clfA = CalibratedClassifierCV(base, method="isotonic", cv=3)
    clfA.fit(X_tr, y_tr)
    oof_A[va_idx] = clfA.predict_proba(X_va)
    test_A_folds.append(clfA.predict_proba(X_test_tfidf))
P_test_A   = np.mean(test_A_folds, axis=0)
oof_pred_A = labels[oof_A.argmax(1)]
print("[A] OOF macro-F1 =", f1_score(y_train, oof_pred_A, average="macro"))

# B：TF-IDF + LogisticRegression
oof_B = np.zeros((len(X_soft_train), L))
test_B_folds = []
for tr_idx, va_idx in skf.split(X_all_tfidf, y_train):
    X_tr, X_va = X_all_tfidf[tr_idx], X_all_tfidf[va_idx]
    y_tr, y_va = y_train[tr_idx], y_train[va_idx]
    baseLR = LogisticRegression(
        solver="saga", penalty="l2", C=2.0, max_iter=200,
        multi_class="multinomial", class_weight="balanced", n_jobs=-1, random_state=SEED
    )
    clfB = CalibratedClassifierCV(baseLR, method="isotonic", cv=3)
    clfB.fit(X_tr, y_tr)
    oof_B[va_idx] = clfB.predict_proba(X_va)
    test_B_folds.append(clfB.predict_proba(X_test_tfidf))
P_test_B   = np.mean(test_B_folds, axis=0)
oof_pred_B = labels[oof_B.argmax(1)]
print("[B] OOF macro-F1 =", f1_score(y_train, oof_pred_B, average="macro"))

# C：NB-SVM
oof_C = np.zeros((len(X_soft_train), C))
test_C_folds = []
for tr_idx, va_idx in skf.split(X_cnt, y_enc_full):
    X_tr, X_va = X_cnt[tr_idx], X_cnt[va_idx]
    y_tr, y_va = y_enc_full[tr_idx], y_enc_full[va_idx]
    preds_val = np.zeros((len(va_idx), C))
    preds_tst = np.zeros((X_cnt_test.shape[0], C))
    for c in range(C):
        r_c = log_count_ratio(X_tr, y_tr, c)
        X_tr_rc = X_tr.multiply(r_c)
        X_va_rc = X_va.multiply(r_c)
        X_te_rc = X_cnt_test.multiply(r_c)
        y_bin = (y_tr==c).astype(int)
        pos = int(y_bin.sum()); neg = len(y_bin)-pos
        w_pos = float(np.sqrt(neg/max(pos,1)))
        svc = LinearSVC(C=1.0, class_weight={1:w_pos, 0:1.0}, random_state=SEED)
        svc.fit(X_tr_rc, y_bin)
        val_score = svc.decision_function(X_va_rc)
        tst_score = svc.decision_function(X_te_rc)
        preds_val[:, c] = 1/(1+np.exp(-val_score))
        preds_tst[:, c] = 1/(1+np.exp(-tst_score))
    preds_val = (preds_val.T / preds_val.sum(1)).T
    preds_tst = (preds_tst.T / preds_tst.sum(1)).T
    oof_C[va_idx] = preds_val
    test_C_folds.append(preds_tst)

idx_map_C = [np.where(le_full.classes_==c)[0][0] for c in labels]
oof_C     = oof_C[:, idx_map_C]
P_test_C  = np.mean(test_C_folds, axis=0)[:, idx_map_C]
oof_pred_C= labels[oof_C.argmax(1)]
print("[C] OOF macro-F1 =", f1_score(y_train, oof_pred_C, average="macro"))

# D：SBERT(+XGB) with TTApnet
name = 'all-mpnet-base-v2'
X_soft_tr, X_soft_te = sbert_soft[name]
X_hard_tr, X_hard_te = sbert_hard[name]

oof_D = np.zeros((len(X_soft_train), L))
test_D_folds = []
skf2 = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
for tr_idx, va_idx in skf2.split(X_soft_tr, y_train_enc):
    X_tr, X_va = X_soft_tr[tr_idx], X_soft_tr[va_idx]
    y_tr, y_va = y_train_enc[tr_idx], y_train_enc[va_idx]

    # BorderlineSMOTE + Effective-number
    cnt = Counter(y_tr); maj = max(cnt.values())
    sampling_strategy = {c: max(v, int(0.55*maj)) for c, v in cnt.items()}
    sm = BorderlineSMOTE(k_neighbors=3, sampling_strategy=sampling_strategy, random_state=SEED)
    X_tr_sm, y_tr_sm = sm.fit_resample(X_tr, y_tr)
    cls_w = effective_num_weights(y_tr_sm, L, beta=0.999)
    sw_tr = cls_w[y_tr_sm]

    xgbD = xgb.XGBClassifier(
        objective='multi:softprob', num_class=L,
        learning_rate=0.10, max_depth=6, n_estimators=420,
        subsample=0.9, colsample_bytree=0.95,
        eval_metric='mlogloss', tree_method='hist',
        reg_alpha=0.0, reg_lambda=1.0, random_state=SEED
    )
    xgbD.fit(X_tr_sm, y_tr_sm, sample_weight=sw_tr)
    proba_va_soft = xgbD.predict_proba(X_soft_tr[va_idx])
    proba_va_hard = xgbD.predict_proba(X_hard_tr[va_idx])
    proba_va = (proba_va_soft + proba_va_hard) / 2.0

    proba_te_soft = xgbD.predict_proba(X_soft_te)
    proba_te_hard = xgbD.predict_proba(X_hard_te)
    proba_te = (proba_te_soft + proba_te_hard) / 2.0

    idx_map_D = [np.where(le_xgb.classes_==c)[0][0] for c in labels]
    oof_D[va_idx] = proba_va[:, idx_map_D]
    test_D_folds.append(proba_te[:, idx_map_D])

P_test_D   = np.mean(test_D_folds, axis=0)
oof_pred_D = labels[oof_D.argmax(1)]
print("[D] OOF macro-F1 =", f1_score(y_train, oof_pred_D, average="macro"))

# E：SBERT(+CalibSVC) with TTA（soft/hard）
oof_E = np.zeros((len(X_soft_train), L))
test_E_folds = []
for tr_idx, va_idx in skf2.split(X_soft_tr, y_train):
    X_tr, y_tr = X_soft_tr[tr_idx], y_train[tr_idx]
    base = LinearSVC(C=1.0, class_weight="balanced", random_state=SEED)
    clfE = CalibratedClassifierCV(base, method="isotonic", cv=3)
    clfE.fit(X_tr, y_tr)

    # TTA
    p_va_soft  = clfE.predict_proba(X_soft_tr[va_idx])
    p_va_hard  = clfE.predict_proba(X_hard_tr[va_idx])
    p_te_soft  = clfE.predict_proba(X_soft_te)
    p_te_hard  = clfE.predict_proba(X_hard_te)

    oof_E[va_idx] = (p_va_soft + p_va_hard)/2.0
    test_E_folds.append((p_te_soft + p_te_hard)/2.0)

P_test_E   = np.mean(test_E_folds, axis=0)
oof_pred_E = labels[oof_E.argmax(1)]
print("[E] OOF macro-F1 =", f1_score(y_train, oof_pred_E, average="macro"))

# F：SBERT(+XGB) with TTA（soft/hard） for paraphrase-mpnet
name2 = 'paraphrase-mpnet-base-v2'
X2_soft_tr, X2_soft_te = sbert_soft[name2]
X2_hard_tr, X2_hard_te = sbert_hard[name2]

oof_F = np.zeros((len(X_soft_train), L))
test_F_folds = []
for tr_idx, va_idx in skf2.split(X2_soft_tr, y_train_enc):
    X_tr, X_va = X2_soft_tr[tr_idx], X2_soft_tr[va_idx]
    y_tr, y_va = y_train_enc[tr_idx], y_train_enc[va_idx]

    cnt = Counter(y_tr); maj = max(cnt.values())
    sampling_strategy = {c: max(v, int(0.55*maj)) for c, v in cnt.items()}
    sm = BorderlineSMOTE(k_neighbors=3, sampling_strategy=sampling_strategy, random_state=SEED)
    X_tr_sm, y_tr_sm = sm.fit_resample(X_tr, y_tr)
    cls_w = effective_num_weights(y_tr_sm, L, beta=0.999)
    sw_tr = cls_w[y_tr_sm]

    xgbF = xgb.XGBClassifier(
        objective='multi:softprob', num_class=L,
        learning_rate=0.10, max_depth=6, n_estimators=420,
        subsample=0.9, colsample_bytree=0.95,
        eval_metric='mlogloss', tree_method='hist',
        reg_alpha=0.0, reg_lambda=1.0, random_state=SEED
    )
    xgbF.fit(X_tr_sm, y_tr_sm, sample_weight=sw_tr)

    proba_va = (xgbF.predict_proba(X2_soft_tr[va_idx]) + xgbF.predict_proba(X2_hard_tr[va_idx])) / 2.0
    proba_te = (xgbF.predict_proba(X2_soft_te) + xgbF.predict_proba(X2_hard_te)) / 2.0

    idx_map_F = [np.where(le_xgb.classes_==c)[0][0] for c in labels]
    oof_F[va_idx] = proba_va[:, idx_map_F]
    test_F_folds.append(proba_te[:, idx_map_F])

P_test_F   = np.mean(test_F_folds, axis=0)
oof_pred_F = labels[oof_F.argmax(1)]
print("[F SBERT(paraphrase-mpnet)+XGB+TTA] OOF macro-F1 =", f1_score(y_train, oof_pred_F, average="macro"))

# Stacking（A/B/C/D/E/F）+ taus + Per-class Logit Bias + Pairwise flip
P_oof = np.hstack([oof_A, oof_B, oof_C, oof_D, oof_E, oof_F])   # [N, 6*L]
P_tst = np.hstack([P_test_A, P_test_B, P_test_C, P_test_D, P_test_E, P_test_F])

blender = LogisticRegression(
    solver="lbfgs", multi_class="multinomial",
    class_weight="balanced", max_iter=400, random_state=SEED
)
blender.fit(P_oof, y_train)
proba_oof_bl = blender.predict_proba(P_oof)
base_pred    = proba_oof_bl.argmax(1)
print("[STACK(raw)] OOF macro-F1 =", f1_score(y_train, labels[base_pred], average="macro"))

taus = np.ones(L)
best_f1 = f1_score(y_train, labels[base_pred], average="macro")
for j in range(L):
    best_tau_j, best_f1_j = 1.0, best_f1
    for t in np.linspace(0.6, 1.8, 13):
        P = proba_oof_bl.copy()
        P[:, j] = P[:, j] ** (1.0 / t)
        P = (P.T / P.sum(1)).T
        pred = P.argmax(1)
        f1 = f1_score(y_train, labels[pred], average="macro")
        if f1 > best_f1_j:
            best_f1_j, best_tau_j = f1, t
    taus[j] = best_tau_j
    proba_oof_bl[:, j] = proba_oof_bl[:, j] ** (1.0 / best_tau_j)
    proba_oof_bl = (proba_oof_bl.T / proba_oof_bl.sum(1)).T
    best_f1 = best_f1_j

print("Best taus per class:", dict(zip(labels, taus)))
print("[STACK+Temp] OOF macro-F1 =", best_f1)

#Per-class Logit Bias
eps = 1e-9
def prob_to_logits(P):
    return np.log(np.clip(P, eps, None))

logits_oof = prob_to_logits(proba_oof_bl)
b = np.zeros(L, dtype=float)
best_f1_bias = best_f1

grid = np.linspace(-0.8, 0.8, 17)
for it in range(2):
    improved = False
    for j in range(L):
        best_bj, best_local = b[j], best_f1_bias
        for bj in grid:
            b_try = b.copy()
            b_try[j] = bj
            z = logits_oof + b_try
            P = np.exp(z); P = (P.T / P.sum(1)).T
            pred = P.argmax(1)
            f1 = f1_score(y_train, labels[pred], average="macro")
            if f1 > best_local:
                best_local, best_bj = f1, bj
        if best_bj != b[j]:
            b[j] = best_bj
            best_f1_bias = best_local
            improved = True
    if not improved:
        break

print("Per-class logit bias b:", dict(zip(labels, b)))
print("[STACK+Temp+Bias] OOF macro-F1 =", best_f1_bias)

#Pairwise margin flip
P_oof_bias = np.exp(logits_oof + b); P_oof_bias = (P_oof_bias.T / P_oof_bias.sum(1)).T
pred_labels = labels[P_oof_bias.argmax(1)]
cm = confusion_matrix(y_train, pred_labels, labels=labels)
pairs = []
for i in range(L):
    for j in range(L):
        if i!=j:
            pairs.append(((labels[i], labels[j]), cm[i,j] + cm[j,i]))
pairs = [p[0] for p in sorted(pairs, key=lambda x: x[1], reverse=True)[:4]]

pair_tau = {}
P_curr = P_oof_bias.copy()
for (A,B) in pairs:
    ia, ib = label2idx[A], label2idx[B]
    best_pair_f1, best_tau = -1, 1.0
    for t in np.linspace(0.8, 1.4, 13):
        pred = P_curr.argmax(1)
        pa = P_curr[:, ia]; pb = P_curr[:, ib]
        mask = (pred==ia) & (pb/np.clip(pa,1e-8,None) > t)
        pred_adj = pred.copy()
        pred_adj[mask] = ib
        f1 = f1_score(y_train, labels[pred_adj], average="macro")
        if f1 > best_pair_f1:
            best_pair_f1, best_tau = f1, t
    pair_tau[(A,B)] = best_tau

print("Top confused pairs & τ:", pair_tau)

# test
proba_tst_bl = blender.predict_proba(P_tst)
for j in range(L):
    proba_tst_bl[:, j] = proba_tst_bl[:, j] ** (1.0 / taus[j])
proba_tst_bl = (proba_tst_bl.T / np.clip(proba_tst_bl.sum(1), 1e-8, None)).T

logits_tst = np.log(np.clip(proba_tst_bl, 1e-9, None))
P_tst_bias = np.exp(logits_tst + b); P_tst_bias = (P_tst_bias.T / P_tst_bias.sum(1)).T
pred_tst = P_tst_bias.argmax(1)

# Pairwise flip
for (A,B), tau in pair_tau.items():
    ia, ib = label2idx[A], label2idx[B]
    pa = P_tst_bias[:, ia]; pb = P_tst_bias[:, ib]
    mask = (pred_tst==ia) & (pb/np.clip(pa,1e-8,None) > tau)
    pred_tst[mask] = ib

test_pred = labels[pred_tst]
submission = pd.DataFrame({"id": test_df["id"], "emotion": test_pred})
submission.to_csv("submission_final_v3.csv", index=False)
print("\nsubmission_final_v3.csv ok ！")
# Out:
# [A] OOF macro-F1 = 0.4119480651846676
# [B] OOF macro-F1 = 0.4320760878127832
# [C] OOF macro-F1 = 0.3975962332943688
# [D] OOF macro-F1 = 0.4074775066117025
# [E] OOF macro-F1 = 0.39194348593533196
# [F SBERT(paraphrase-mpnet)+XGB+TTA] OOF macro-F1 = 0.435784690291597
# [STACK(raw)] OOF macro-F1 = 0.4972627910279093
# Best taus per class: {'anger': np.float64(1.5), 'disgust': np.float64(0.8), 'fear': np.float64(0.6), 'joy': np.float64(1.8), 'sadness': np.float64(1.0), 'surprise': np.float64(1.1)}
# [STACK+Temp] OOF macro-F1 = 0.5160587787836136
# Per-class logit bias b: {'anger': np.float64(0.0), 'disgust': np.float64(0.0), 'fear': np.float64(0.09999999999999998), 'joy': np.float64(0.0), 'sadness': np.float64(0.0), 'surprise': np.float64(0.0)}
# [STACK+Temp+Bias] OOF macro-F1 = 0.5164202812299358
# Top confused pairs & τ: {('anger', 'joy'): np.float64(0.9), ('joy', 'anger'): np.float64(0.95), ('joy', 'surprise'): np.float64(1.0), ('surprise', 'joy'): np.float64(1.0)}
#
# ...
